# %% [markdown]
# # Custom Visualization Examples
#
# Create interactive plots using validation results.

# %%
import sys
sys.path.append('../src')

from enhanced_visualization import EnhancedVisualizer

# Example data
data = {
    'name': ['PDBDEV_00000001', 'PDBDEV_00000010', 'PDBDEV_00000020'],
    'size_mb': [1.6, 5.8, 2.1],
    'time_min': [2.5, 9.0, 3.0],
    'status': ['Pass', 'Pass', 'Pass'],
    'components': ['SAS+CXMS', 'EM', 'SAS'],
    'color': ['green', 'green', 'green']
}

viz = EnhancedVisualizer()
viz.create_interactive_plot(data, 'interactive_demo.html')

print("✓ Interactive plot created: interactive_demo.html")
